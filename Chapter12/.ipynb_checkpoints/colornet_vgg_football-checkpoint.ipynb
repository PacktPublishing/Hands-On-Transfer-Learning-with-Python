# %%
from google.colab import files
import keras
#from keras.applications.inception_resnet_v2 import InceptionResNetV2
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.engine import Layer
#from keras.applications.inception_resnet_v2 import preprocess_input
from keras.applications.vgg16 import preprocess_input
from keras.layers import Conv2D, UpSampling2D, InputLayer, Conv2DTranspose, Input, Reshape, merge, concatenate, Activation, Dense, Dropout, Flatten
from keras.layers.normalization import BatchNormalization
from keras.callbacks import TensorBoard 
from keras.models import Sequential, Model
from keras.layers.core import RepeatVector, Permute
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from skimage.color import rgb2lab, lab2rgb, rgb2gray, gray2rgb,convert_colorspace
from skimage.transform import resize
from skimage.io import imsave,imshow
import numpy as np
import os
import random
import tensorflow as tf

import scipy as sp
import scipy.ndimage as spi

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
def upload_files():
  uploaded = files.upload()
  for k, v in uploaded.items():
    open(k, 'wb').write(v)
  return list(uploaded.keys())

# %%
file_list = upload_files()
# Out:
#      <input type="file" id="files-c8d55cd5-aad6-4578-928a-a001f63a2799" name="files[]" multiple disabled />
#      <output id="result-c8d55cd5-aad6-4578-928a-a001f63a2799">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 0dc3e95a9954c5d50e5ddac5bf774e09.jpeg to 0dc3e95a9954c5d50e5ddac5bf774e09 (1).jpeg
# Saving 5a2987b714c15456c0e038dabcf426e2.jpeg to 5a2987b714c15456c0e038dabcf426e2 (1).jpeg
# Saving 5a0728978e9a5180076ec357bc28c92e.jpeg to 5a0728978e9a5180076ec357bc28c92e (1).jpeg
# Saving 6a47074ff275acedfa82ffbc9025b703.jpeg to 6a47074ff275acedfa82ffbc9025b703 (1).jpeg
# Saving 6d905979f4788767939883c0f8b4250b.jpeg to 6d905979f4788767939883c0f8b4250b (1).jpeg
# Saving 07c4859f54fb3184aebca9a7b3aa5317.jpeg to 07c4859f54fb3184aebca9a7b3aa5317 (1).jpeg
# Saving 7ed962e763ce17c16df44cfa96dfd047.jpeg to 7ed962e763ce17c16df44cfa96dfd047 (1).jpeg
# Saving 58fd582ca79217457b0d8807a6302824.jpeg to 58fd582ca79217457b0d8807a6302824 (1).jpeg
# Saving 328e41c2fbc194b0f8900007a61c6d4a.jpeg to 328e41c2fbc194b0f8900007a61c6d4a (1).jpeg
# Saving 663b353d812988e7635ce6709414d6aa.jpeg to 663b353d812988e7635ce6709414d6aa (1).jpeg
# Saving 1261ea1079ab97b732812e328c3a5c48.jpeg to 1261ea1079ab97b732812e328c3a5c48 (1).jpeg
# Saving 8587f219580ae6f207490ff02f853df3.jpeg to 8587f219580ae6f207490ff02f853df3 (1).jpeg
# Saving ae69df2e9995ee238f5ea93090a3981d.jpeg to ae69df2e9995ee238f5ea93090a3981d (1).jpeg
# Saving b208394092522e1a74b7ce9d8b558022.jpeg to b208394092522e1a74b7ce9d8b558022 (1).jpeg
# Saving bb9d9ece213507e6c45852633c6e61e8.jpeg to bb9d9ece213507e6c45852633c6e61e8 (1).jpeg
# Saving cb2af8fbb9cd6d48eb1009c68349cb1e.jpeg to cb2af8fbb9cd6d48eb1009c68349cb1e (1).jpeg
# Saving cbb19bd188a96067f478c0a9b1559844.jpeg to cbb19bd188a96067f478c0a9b1559844 (1).jpeg
# Saving e72e923ffc4d51faf1a99d09bd59896a.jpeg to e72e923ffc4d51faf1a99d09bd59896a (1).jpeg
# Saving fe79cd9cda63a4af3924d2718b7e775a.jpeg to fe79cd9cda63a4af3924d2718b7e775a (1).jpeg
# Saving ff20b4d22ed3e1e8829768201d110f53.jpeg to ff20b4d22ed3e1e8829768201d110f53 (1).jpeg

# %%
def prep_data(file_list=[],dir_path=None,dim_x=256,dim_y=256):
    #Get images
    X = []
    for filename in file_list:
        X.append(img_to_array(sp.misc.imresize(load_img(dir_path+filename), (dim_x, dim_y))))
    X = np.array(X, dtype=np.float64)
    X = 1.0/255*X
    return X

# %%
#Load weights
vgg16 = VGG16(weights=r'imagenet', include_top=True)
vgg16.graph = tf.get_default_graph()

# %%
train_files,test_files =train_test_split(file_list, 
                                            test_size=0.3,  
                                            random_state=42)

# %%
DIM = 256

# %%
X_train = prep_data(file_list=train_files,
                    dir_path='',
                    dim_x=DIM,dim_y=DIM)
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /usr/local/lib/python3.6/dist-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):

# %%
embed_input = Input(shape=(1000,))

#Encoder
encoder_input = Input(shape=(DIM, DIM, 1,))
encoder_output = Conv2D(64, (3,3), activation='relu', padding='same', strides=2)(encoder_input)
encoder_output = Conv2D(128, (3,3), activation='relu', padding='same')(encoder_output)
encoder_output = Conv2D(125, (3,3), activation='relu', padding='same', strides=2)(encoder_output)
encoder_output = Conv2D(256, (3,3), activation='relu', padding='same')(encoder_output)
encoder_output = Conv2D(256, (3,3), activation='relu', padding='same', strides=2)(encoder_output)
encoder_output = Conv2D(512, (3,3), activation='relu', padding='same')(encoder_output)
encoder_output = Conv2D(256, (3,3), activation='relu', padding='same')(encoder_output)

#Fusion
fusion_output = RepeatVector(32*32)(embed_input) 
fusion_output = Reshape(([32,32, 1000]))(fusion_output)
fusion_output = concatenate([encoder_output, fusion_output], axis=3) 
fusion_output = Conv2D(DIM, (1, 1), activation='relu', padding='same')(fusion_output) 

#Decoder
decoder_output = Conv2D(128, (3,3), activation='relu', padding='same')(fusion_output)
decoder_output = UpSampling2D((2, 2))(decoder_output)
decoder_output = Conv2D(64, (3,3), activation='relu', padding='same')(decoder_output)
decoder_output = UpSampling2D((2, 2))(decoder_output)
decoder_output = Conv2D(32, (3,3), activation='relu', padding='same')(decoder_output)
decoder_output = Conv2D(16, (3,3), activation='relu', padding='same')(decoder_output)
decoder_output = Conv2D(2, (3, 3), activation='tanh', padding='same')(decoder_output)
decoder_output = UpSampling2D((2, 2))(decoder_output)

model = Model(inputs=[encoder_input, embed_input], outputs=decoder_output)

# %%
#Create embedding
def create_vgg_embedding(grayscaled_rgb):
    grayscaled_rgb_resized = []
    for i in grayscaled_rgb:
        i = resize(i, (224, 224, 3), mode='constant')
        grayscaled_rgb_resized.append(i)
    grayscaled_rgb_resized = np.array(grayscaled_rgb_resized)
    grayscaled_rgb_resized = preprocess_input(grayscaled_rgb_resized)
    with vgg16.graph.as_default():
        embed = vgg16.predict(grayscaled_rgb_resized)
    return embed

# Image transformer
datagen = ImageDataGenerator(
        shear_range=0.2,
        zoom_range=0.2,
        rotation_range=20,
        horizontal_flip=True)

#Generate training data
batch_size = 20

def image_a_b_gen(batch_size,X):
    for batch in datagen.flow(X, batch_size=batch_size):
        grayscaled_rgb = gray2rgb(rgb2gray(batch))
        lab_batch = rgb2lab(batch)
        X_batch = lab_batch[:,:,:,0]
        X_batch = X_batch.reshape(X_batch.shape+(1,))
        Y_batch = lab_batch[:,:,:,1:] / 128
        yield ([X_batch, create_vgg_embedding(grayscaled_rgb)], Y_batch)

# %%
model.compile(optimizer='adam', loss='mse')

# %%
EPOCH=750

# %%
history = model.fit_generator(image_a_b_gen(batch_size,X_train), 
                              epochs=EPOCH, 
                              steps_per_epoch=2)
# Out:
# Epoch 1/750
# 2/2 [==============================] - 8s 4s/step - loss: 0.3262
# Epoch 2/750
# 2/2 [==============================] - 1s 689ms/step - loss: 0.1034
# Epoch 3/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0275
# Epoch 4/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0255
# Epoch 5/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0248
# Epoch 6/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0246
# Epoch 7/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0251
# Epoch 8/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0239
# Epoch 9/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0238
# Epoch 10/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0242
# Epoch 11/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0233
# Epoch 12/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0238
# Epoch 13/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0234
# Epoch 14/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0242
# Epoch 15/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0239
# Epoch 16/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0243
# Epoch 17/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0237
# Epoch 18/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0234
# Epoch 19/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0227
# Epoch 20/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0230
# Epoch 21/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0231
# Epoch 22/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0228
# Epoch 23/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0220
# Epoch 24/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0262
# Epoch 25/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0240
# Epoch 26/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0253
# Epoch 27/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0247
# Epoch 28/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0241
# Epoch 29/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0239
# Epoch 30/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0231
# Epoch 31/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0233
# Epoch 32/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0234
# Epoch 33/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0235
# Epoch 34/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0227
# Epoch 35/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0234
# Epoch 36/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0238
# Epoch 37/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0230
# Epoch 38/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0232
# Epoch 39/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0232
# Epoch 40/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0234
# Epoch 41/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0227
# Epoch 42/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0235
# Epoch 43/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0224
# Epoch 44/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0230
# Epoch 45/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0230
# Epoch 46/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0224
# Epoch 47/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0222
# Epoch 48/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0228
# Epoch 49/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0219
# Epoch 50/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0217
# Epoch 51/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0216
# Epoch 52/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0235
# Epoch 53/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0227
# Epoch 54/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0228
# Epoch 55/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0225
# Epoch 56/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0227
# Epoch 57/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0227
# Epoch 58/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0228
# Epoch 59/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0213
# Epoch 60/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0225
# Epoch 61/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0237
# Epoch 62/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0234
# Epoch 63/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0219
# Epoch 64/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0239
# Epoch 65/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0227
# Epoch 66/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0229
# Epoch 67/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0223
# Epoch 68/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0220
# Epoch 69/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0224
# Epoch 70/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0215
# Epoch 71/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0216
# Epoch 72/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0220
# Epoch 73/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0221
# Epoch 74/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0211
# Epoch 75/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0207
# Epoch 76/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0204
# Epoch 77/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0210
# Epoch 78/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0209
# Epoch 79/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0209
# Epoch 80/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0205
# Epoch 81/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0201
# Epoch 82/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0203
# Epoch 83/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0222
# Epoch 84/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0255
# Epoch 85/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0243
# Epoch 86/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0263
# Epoch 87/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0250
# Epoch 88/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0245
# Epoch 89/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0241
# Epoch 90/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0245
# Epoch 91/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0255
# Epoch 92/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0239
# Epoch 93/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0235
# Epoch 94/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0235
# Epoch 95/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0223
# Epoch 96/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0229
# Epoch 97/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0226
# Epoch 98/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0229
# Epoch 99/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0230
# Epoch 100/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0228
# Epoch 101/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0224
# Epoch 102/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0226
# Epoch 103/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0220
# Epoch 104/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0224
# Epoch 105/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0223
# Epoch 106/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.
750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0036
# Epoch 478/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0038
# Epoch 479/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0035
# Epoch 480/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0035
# Epoch 481/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0034
# Epoch 482/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0036
# Epoch 483/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0035
# Epoch 484/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0036
# Epoch 485/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0037
# Epoch 486/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0035
# Epoch 487/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0040
# Epoch 488/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0040
# Epoch 489/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0038
# Epoch 490/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0038
# Epoch 491/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0035
# Epoch 492/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0036
# Epoch 493/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0036
# Epoch 494/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0037
# Epoch 495/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0036
# Epoch 496/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0035
# Epoch 497/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0035
# Epoch 498/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0036
# Epoch 499/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0035
# Epoch 500/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0034
# Epoch 501/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0034
# Epoch 502/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0034
# Epoch 503/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0035
# Epoch 504/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0034
# Epoch 505/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0033
# Epoch 506/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0033
# Epoch 507/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0033
# Epoch 508/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0035
# Epoch 509/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0035
# Epoch 510/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0033
# Epoch 511/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0032
# Epoch 512/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0034
# Epoch 513/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0032
# Epoch 514/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0034
# Epoch 515/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0033
# Epoch 516/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0032
# Epoch 517/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0033
# Epoch 518/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0033
# Epoch 519/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0032
# Epoch 520/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0031
# Epoch 521/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0033
# Epoch 522/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0031
# Epoch 523/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0031
# Epoch 524/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0032
# Epoch 525/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0032
# Epoch 526/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0033
# Epoch 527/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0033
# Epoch 528/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0034
# Epoch 529/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0032
# Epoch 530/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0033
# Epoch 531/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0031
# Epoch 532/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0032
# Epoch 533/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0031
# Epoch 534/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0032
# Epoch 535/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0033
# Epoch 536/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0033
# Epoch 537/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0033
# Epoch 538/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0032
# Epoch 539/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0032
# Epoch 540/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0032
# Epoch 541/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0032
# Epoch 542/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0032
# Epoch 543/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0032
# Epoch 544/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0032
# Epoch 545/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0033
# Epoch 546/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0031
# Epoch 547/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0031
# Epoch 548/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0031
# Epoch 549/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0032
# Epoch 550/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0030
# Epoch 551/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0031
# Epoch 552/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0031
# Epoch 553/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0032
# Epoch 554/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0031
# Epoch 555/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0032
# Epoch 556/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0032
# Epoch 557/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0031
# Epoch 558/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0031
# Epoch 559/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0032
# Epoch 560/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0032
# Epoch 561/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0032
# Epoch 562/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0030
# Epoch 563/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0033
# Epoch 564/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0031
# Epoch 565/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0031
# Epoch 566/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0033
# Epoch 567/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0032
# Epoch 568/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0031
# Epoch 569/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0031
# Epoch 570/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0031
# Epoch 571/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0031
# Epoch 572/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0031
# Epoch 573/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0031
# Epoch 574/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0031
# Epoch 575/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0032
# Epoch 576/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0029
# Epoch 577/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0030
# Epoch 578/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0030
# Epoch 579/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0031
# Epoch 580/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0029
# Epoch 581/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0030
# Epoch 582/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0030
# Epoch 583/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0030
# Epoch 584/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0030
# Epoch 585/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0029
# Epoch 586/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0029
# Epoch 587/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0029
# Epoch 588/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0029
# Epoch 589/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0030
# Epoch 590/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0029
# Epoch 591/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0030
# Epoch 592/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0030
# Epoch 593/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0029
# Epoch 594/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0030
# Epoch 595/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0028
# Epoch 596/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0031
# Epoch 597/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0029
# Epoch 598/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0030
# Epoch 599/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0030
# Epoch 600/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0030
# Epoch 601/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0030
# Epoch 602/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0030
# Epoch 603/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0030
# Epoch 604/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0030
# Epoch 605/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0029
# Epoch 606/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0029
# Epoch 607/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0030
# Epoch 608/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0030
# Epoch 609/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0030
# Epoch 610/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0029
# Epoch 611/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0030
# Epoch 612/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0030
# Epoch 613/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0031
# Epoch 614/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0030
# Epoch 615/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0030
# Epoch 616/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0030
# Epoch 617/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0029
# Epoch 618/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0030
# Epoch 619/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0029
# Epoch 620/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0030
# Epoch 621/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0029
# Epoch 622/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0029
# Epoch 623/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0029
# Epoch 624/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0029
# Epoch 625/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0029
# Epoch 626/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0030
# Epoch 627/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0028
# Epoch 628/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0029
# Epoch 629/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0028
# Epoch 630/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0029
# Epoch 631/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0028
# Epoch 632/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0028
# Epoch 633/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0028
# Epoch 634/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0028
# Epoch 635/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0027
# Epoch 636/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0028
# Epoch 637/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0028
# Epoch 638/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0028
# Epoch 639/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0028
# Epoch 640/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0029
# Epoch 641/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0028
# Epoch 642/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0028
# Epoch 643/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0029
# Epoch 644/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0027
# Epoch 645/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0026
# Epoch 646/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0028
# Epoch 647/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0027
# Epoch 648/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0029
# Epoch 649/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0029
# Epoch 650/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0029
# Epoch 651/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0029
# Epoch 652/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0029
# Epoch 653/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0028
# Epoch 654/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0030
# Epoch 655/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0029
# Epoch 656/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0028
# Epoch 657/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0029
# Epoch 658/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0028
# Epoch 659/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0028
# Epoch 660/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0028
# Epoch 661/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0028
# Epoch 662/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0028
# Epoch 663/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0027
# Epoch 664/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0029
# Epoch 665/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0027
# Epoch 666/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0029
# Epoch 667/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0028
# Epoch 668/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0028
# Epoch 669/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0028
# Epoch 670/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0027
# Epoch 671/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0027
# Epoch 672/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0027
# Epoch 673/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0027
# Epoch 674/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0028
# Epoch 675/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0027
# Epoch 676/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0027
# Epoch 677/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0029
# Epoch 678/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0027
# Epoch 679/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0026
# Epoch 680/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0026
# Epoch 681/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0026
# Epoch 682/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0026
# Epoch 683/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0027
# Epoch 684/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0026
# Epoch 685/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0027
# Epoch 686/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0026
# Epoch 687/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0027
# Epoch 688/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0028
# Epoch 689/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0027
# Epoch 690/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0027
# Epoch 691/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0028
# Epoch 692/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0027
# Epoch 693/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0027
# Epoch 694/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0027
# Epoch 695/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0029
# Epoch 696/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0027
# Epoch 697/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0028
# Epoch 698/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0027
# Epoch 699/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0027
# Epoch 700/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0028
# Epoch 701/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0027
# Epoch 702/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0027
# Epoch 703/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0026
# Epoch 704/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0027
# Epoch 705/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0026
# Epoch 706/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0026
# Epoch 707/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0027
# Epoch 708/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0026
# Epoch 709/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0027
# Epoch 710/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0027
# Epoch 711/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0026
# Epoch 712/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0025
# Epoch 713/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0027
# Epoch 714/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0026
# Epoch 715/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0027
# Epoch 716/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0026
# Epoch 717/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0026
# Epoch 718/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0026
# Epoch 719/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0026
# Epoch 720/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0026
# Epoch 721/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0026
# Epoch 722/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0026
# Epoch 723/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0026
# Epoch 724/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0026
# Epoch 725/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0027
# Epoch 726/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0026
# Epoch 727/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0026
# Epoch 728/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0026
# Epoch 729/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0026
# Epoch 730/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0026
# Epoch 731/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0027
# Epoch 732/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0026
# Epoch 733/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0025
# Epoch 734/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0025
# Epoch 735/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0026
# Epoch 736/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0025
# Epoch 737/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0026
# Epoch 738/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0025
# Epoch 739/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0025
# Epoch 740/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0025
# Epoch 741/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0025
# Epoch 742/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0025
# Epoch 743/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0026
# Epoch 744/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0025
# Epoch 745/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0026
# Epoch 746/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0026
# Epoch 747/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0025
# Epoch 748/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0025
# Epoch 749/750
# 2/2 [==============================] - 3s 1s/step - loss: 0.0025
# Epoch 750/750
# 2/2 [==============================] - 2s 1s/step - loss: 0.0025

# %%
f, (ax2) = plt.subplots(1, 1, figsize=(25, 5))
t = f.suptitle('ColorNet Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

epochs = list(range(1,EPOCH+1))

ax2.plot(epochs, history.history['loss'], label='Train Loss')
#ax2.plot(epochs, history.history['val_loss'], label='Validation Loss')
ax2.set_xticks(epochs)
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")
plt.show()

# %%
#Make predictions on validation images
# Change to '/data/images/Test/' to use all the 500 test images
IMG_DIR = ''
color_me = []
for filename in test_files:
    color_me.append(sp.misc.imresize(load_img(IMG_DIR+filename), (DIM, DIM)))
color_me = np.array(color_me, dtype=float)
color_me = 1.0/255*color_me
color_me = gray2rgb(rgb2gray(color_me))
color_me_embed = create_vgg_embedding(color_me)
color_me = rgb2lab(color_me)[:,:,:,0]
color_me = color_me.reshape(color_me.shape+(1,))
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /usr/local/lib/python3.6/dist-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):

# %%
# Test model
output = model.predict([color_me, color_me_embed])
output = output * 128

# %%
filenames = test_files
# Output colorizations
for i in range(len(output)):
    fig = plt.figure(figsize=(8,8))
    cur = np.zeros((DIM,DIM, 3))
    cur[:,:,0] = color_me[i][:,:,0]
    cur[:,:,1:] = output[i]
    
    img_obj = load_img(IMG_DIR+filenames[i])
    
    fig.add_subplot(1, 3, 1)
    plt.axis('off')
    
    grayed_img = gray2rgb(rgb2gray(img_to_array(img_obj)/255))
    plt.imshow(grayed_img)
    plt.title("grayscale")
    
    fig.add_subplot(1, 3, 2)
    plt.axis('off')
    imshow(lab2rgb(cur))
    plt.title("hallucination")
    
    fig.add_subplot(1, 3, 3)
    plt.imshow(img_obj)
    plt.title("original")
    plt.axis('off')
    plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# /usr/local/lib/python3.6/dist-packages/skimage/color/colorconv.py:985: UserWarning: Color data out of range: Z < 0 in 7 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
